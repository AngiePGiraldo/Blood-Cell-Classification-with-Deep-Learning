# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

# Define hiperparámetros
batch_size = 64
epochs = 15
input_shape = (50, 50, 3)  # Ajusta las dimensiones según tus imágenes
num_classes = 4  # Para los cuatro tipos de células sanguíneas

# Crear el modelo de la red neuronal0
model = Sequential()
model.add(Conv2D(64, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Compilar el modelo
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Data augmentation (aumento de datos) para mejorar el rendimiento
datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# Cargar el conjunto de datos (asegúrate de tener tus imágenes en las carpetas correctas)
train_generator = datagen.flow_from_directory(
    'C:/Users/paola/OneDrive/Escritorio/parcial2Dl/images/TRAIN',  # Ruta al conjunto de entrenamiento
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical')

test_generator = datagen.flow_from_directory(
    'C:/Users/paola/OneDrive/Escritorio/parcial2Dl/images/TEST',  # Ruta al conjunto de prueba
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical')

# Entrenar el modelo
model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=len(test_generator))

# Evaluar el modelo
score = model.evaluate(test_generator, steps=len(test_generator))
print(f'Precisión: {score[1]*100}%')
# Out:
# Found 9957 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.
# Epoch 1/15
# 156/156 [==============================] - 67s 424ms/step - loss: 1.3869 - accuracy: 0.2469 - val_loss: 1.3840 - val_accuracy: 0.3655
# Epoch 2/15
# 156/156 [==============================] - 62s 397ms/step - loss: 1.3715 - accuracy: 0.2762 - val_loss: 1.3101 - val_accuracy: 0.3675
# Epoch 3/15
# 156/156 [==============================] - 61s 388ms/step - loss: 1.1654 - accuracy: 0.4145 - val_loss: 1.0665 - val_accuracy: 0.4865
# Epoch 4/15
# 156/156 [==============================] - 61s 390ms/step - loss: 1.0844 - accuracy: 0.4660 - val_loss: 0.9831 - val_accuracy: 0.5497
# Epoch 5/15
# 156/156 [==============================] - 66s 422ms/step - loss: 1.0389 - accuracy: 0.4874 - val_loss: 0.9730 - val_accuracy: 0.5328
# Epoch 6/15
# 156/156 [==============================] - 62s 400ms/step - loss: 1.0185 - accuracy: 0.5104 - val_loss: 0.9286 - val_accuracy: 0.5678
# Epoch 7/15
# 156/156 [==============================] - 60s 386ms/step - loss: 0.9793 - accuracy: 0.5383 - val_loss: 0.9053 - val_accuracy: 0.5368
# Epoch 8/15
# 156/156 [==============================] - 61s 390ms/step - loss: 0.9329 - accuracy: 0.5760 - val_loss: 0.8600 - val_accuracy: 0.6027
# Epoch 9/15
# 156/156 [==============================] - 63s 405ms/step - loss: 0.8262 - accuracy: 0.6109 - val_loss: 0.7882 - val_accuracy: 0.6128
# Epoch 10/15
# 156/156 [==============================] - 69s 440ms/step - loss: 0.7362 - accuracy: 0.6447 - val_loss: 0.6896 - val_accuracy: 0.6281
# Epoch 11/15
# 156/156 [==============================] - 66s 421ms/step - loss: 0.6733 - accuracy: 0.6732 - val_loss: 0.8058 - val_accuracy: 0.6124
# Epoch 12/15
# 156/156 [==============================] - 67s 427ms/step - loss: 0.6316 - accuracy: 0.6865 - val_loss: 0.7283 - val_accuracy: 0.6494
# Epoch 13/15
# 156/156 [==============================] - 163s 1s/step - loss: 0.5800 - accuracy: 0.7113 - val_loss: 0.7377 - val_accuracy: 0.6329
# Epoch 14/15
# 156/156 [==============================] - 205s 1s/step - loss: 0.5606 - accuracy: 0.7164 - val_loss: 0.7692 - val_accuracy: 0.6232
# Epoch 15/15
# 156/156 [==============================] - 196s 1s/step - loss: 0.5369 - accuracy: 0.7283 - val_loss: 0.7092 - val_accuracy: 0.6687
# 39/39 [==============================] - 33s 807ms/step - loss: 0.7024 - accuracy: 0.6723
# Precisión: 67.22959280014038%
