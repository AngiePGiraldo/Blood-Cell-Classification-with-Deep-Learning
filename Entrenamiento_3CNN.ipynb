# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense

# Define hiperparámetros
batch_size = 32
epochs = 10
input_shape = (50, 50, 3)  # Ajusta las dimensiones según tus imágenes
num_classes = 4  # Para los cuatro tipos de células sanguíneas

# Crear el modelo de la red neuronal0
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# Compilar el modelo
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Data augmentation (aumento de datos) para mejorar el rendimiento
datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# Cargar el conjunto de datos (asegúrate de tener tus imágenes en las carpetas correctas)
train_generator = datagen.flow_from_directory(
    'C:/Users/paola/OneDrive/Escritorio/parcial2Dl/images/TRAIN',  # Ruta al conjunto de entrenamiento
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical')

test_generator = datagen.flow_from_directory(
    'C:/Users/paola/OneDrive/Escritorio/parcial2Dl/images/TEST',  # Ruta al conjunto de prueba
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical')

# Entrenar el modelo
model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=epochs,
    validation_data=test_generator,
    validation_steps=len(test_generator))

# Evaluar el modelo
score = model.evaluate(test_generator, steps=len(test_generator))
print(f'Precisión: {score[1]*100}%')
# Out:
# Found 9957 images belonging to 4 classes.
# Found 2487 images belonging to 4 classes.
# Epoch 1/10
# 312/312 [==============================] - 203s 628ms/step - loss: 1.3871 - accuracy: 0.2549 - val_loss: 1.3861 - val_accuracy: 0.2847
# Epoch 2/10
# 312/312 [==============================] - 212s 675ms/step - loss: 1.3264 - accuracy: 0.3199 - val_loss: 1.1100 - val_accuracy: 0.4383
# Epoch 3/10
# 312/312 [==============================] - 216s 668ms/step - loss: 1.1351 - accuracy: 0.4405 - val_loss: 1.0405 - val_accuracy: 0.5066
# Epoch 4/10
# 312/312 [==============================] - 189s 603ms/step - loss: 1.0731 - accuracy: 0.4730 - val_loss: 1.0386 - val_accuracy: 0.4785
# Epoch 5/10
# 312/312 [==============================] - 240s 769ms/step - loss: 1.0537 - accuracy: 0.4881 - val_loss: 1.0421 - val_accuracy: 0.4733
# Epoch 6/10
# 312/312 [==============================] - 219s 697ms/step - loss: 1.0227 - accuracy: 0.5075 - val_loss: 0.9428 - val_accuracy: 0.5324
# Epoch 7/10
# 312/312 [==============================] - 176s 565ms/step - loss: 0.9920 - accuracy: 0.5214 - val_loss: 0.9138 - val_accuracy: 0.5195
# Epoch 8/10
# 312/312 [==============================] - 238s 763ms/step - loss: 0.9663 - accuracy: 0.5319 - val_loss: 0.8906 - val_accuracy: 0.5328
# Epoch 9/10
# 312/312 [==============================] - 245s 768ms/step - loss: 0.9027 - accuracy: 0.5871 - val_loss: 0.8302 - val_accuracy: 0.5858
# Epoch 10/10
# 312/312 [==============================] - 243s 780ms/step - loss: 0.7859 - accuracy: 0.6510 - val_loss: 0.6817 - val_accuracy: 0.6884
# 78/78 [==============================] - 48s 591ms/step - loss: 0.6796 - accuracy: 0.6860
# Precisión: 68.59670281410217%
